# %%
import os, getpass

token = getpass.getpass("GitHub PAT: ")
if os.path.exists("/content/gemma"):
    # %cd /content/gemma
    # !git pull
else:
    # !git clone https://{token}@github.com/El-Moghazy2/gemma.git /content/gemma
    # %cd /content/gemma
# !pip install -q -r requirements.txt

# %%
import torch
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
import getpass

hf_token = getpass.getpass("HuggingFace Token: ")
# !huggingface-cli login --token {hf_token}

# %%
# !python app.py --share
